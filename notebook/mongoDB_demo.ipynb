# %%
# !pip install pandas pymongo
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
# Collecting pandas
#   Downloading pandas-2.3.0-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting pymongo
#   Downloading pymongo-4.13.2-cp310-cp310-win_amd64.whl.metadata (22 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\archi\anaconda3\anancondan\envs\vehicle\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\archi\anaconda3\anancondan\envs\vehicle\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.0-cp310-cp310-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.1 MB 4.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/11.1 MB 4.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.4/11.1 MB 4.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/11.1 MB 3.7 MB/s eta 0:00:03
#    --------------- ------------------------ 4.2/11.1 MB 4.0 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.1 MB 4.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.1 MB 4.4 MB/s eta 0:00:02
#    -------------------------- ------------- 7.3/11.1 MB 4.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.1/11.1 MB 4.3 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/11.1 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 4.3 MB/s eta 0:00:00
# Downloading pymongo-4.13.2-cp310-cp310-win_amd64.whl (800 kB)
#    ---------------------------------------- 0.0/800.2 kB ? eta -:--:--
#    ---------------------------------------- 800.2/800.2 kB 4.3 MB/s eta 0:00:00
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.9 MB 6.3 MB/s eta 0:00:02
#    ------- -------------------------------- 2.4/12.9 MB 5.8 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/12.9 MB 5.1 MB/s eta 0:00:02
#    ------------ --------------------------- 3.9/12.9 MB 4.8 MB/s eta 0:00:02
#    -------------- ------------------------- 4.7/12.9 MB 4.5 MB/s eta 0:00:02
#    ------------------ --------------------- 6.0/12.9 MB 4.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.6/12.9 MB 5.1 MB/s eta 0:00:02
#    -------------------------- ------------- 8.7/12.9 MB 5.1 MB/s eta 0:00:01
#    ------------------------------ --------- 10.0/12.9 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.9 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/12.9 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 5.1 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, dnspython, pymongo, pandas
#
#    ---------------------------------------- 0/6 [pytz]
#    ---------------------------------------- 0/6 [pytz]
#    ---------------------------------------- 0/6 [pytz]
#    ------ --------------------------------- 1/6 [tzdata]
#    ------ --------------------------------- 1/6 [tzdata]
#    ------ --------------------------------- 1/6 [tzdata]
#    ------ --------------------------------- 1/6 [tzdata]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    ------------- -------------------------- 2/6 [numpy]
#    -------------------- ------------------- 3/6 [dnspython]
#    -------------------- ------------------- 3/6 [dnspython]
#    -------------------- ------------------- 3/6 [dnspython]
#    -------------------- ------------------- 3/6 [dnspython]
#    -------------------------- ------------- 4/6 [pymongo]
#    -------------------------- ------------- 4/6 [pymongo]
#    -------------------------- ------------- 4/6 [pymongo]
#    -------------------------- ------------- 4/6 [pymongo]
#    -------------------------- ------------- 4/6 [pymongo]
#    -------------------------- ------------- 4/6 [pymongo]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    --------------------------------- ------ 5/6 [pandas]
#    ---------------------------------------- 6/6 [pandas]
#
# Successfully installed dnspython-2.7.0 numpy-2.2.6 pandas-2.3.0 pymongo-4.13.2 pytz-2025.2 tzdata-2025.2
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://sharmaarchit140:1EWTi2zONoOsQl2S@cluster0.bptsdu9.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
rec = collection.insert_many(data)
